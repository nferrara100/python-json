# %% [markdown]
# # XYZ Marketing Data Pipeline
#
# See the `/exports` folder for the output of this pipeline.
#
# Start by installing the requirements below. You should do this in a virtualenv.

# %%
pip install fastparquet openpyxl pandas
# Out:
# Requirement already satisfied: fastparquet in /Users/nick/virtualenvs/data-test/lib/python3.11/site-packages (2023.7.0)
# Requirement already satisfied: openpyxl in /Users/nick/virtualenvs/data-test/lib/python3.11/site-packages (3.1.2)
# Requirement already satisfied: pandas in /Users/nick/virtualenvs/data-test/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: numpy>=1.20.3 in /Users/nick/virtualenvs/data-test/lib/python3.11/site-packages (from fastparquet) (1.25.1)
# Requirement already satisfied: cramjam>=2.3 in /Users/nick/virtualenvs/data-test/lib/python3.11/site-packages (from fastparquet) (2.6.2)
# Requirement already satisfied: fsspec in /Users/nick/virtualenvs/data-test/lib/python3.11/site-packages (from fastparquet) (2023.6.0)
# Requirement already satisfied: packaging in /Users/nick/virtualenvs/data-test/lib/python3.11/site-packages (from fastparquet) (23.1)
# Requirement already satisfied: et-xmlfile in /Users/nick/virtualenvs/data-test/lib/python3.11/site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/nick/virtualenvs/data-test/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/nick/virtualenvs/data-test/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/nick/virtualenvs/data-test/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/nick/virtualenvs/data-test/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# We'll use Pandas to import the data from the sheets we expect. Additional sheets can be
# added below.

# %%
import pandas as pd

filename = "Senior Full Stack- Interview Task Data.xlsx"
transactions = pd.read_excel(filename, sheet_name="transactions")
transactions
# Out:
#     InvoiceNo StockCode ProductID  Quantity  UnitPrice CustomerID
# 0        1001    ABC123    PRD101         5      10.99    CUST101
# 1        1002    DEF456    PRD102         3       5.49    CUST102
# 2        1003    GHI789    PRD103         2       7.99    CUST103
# 3        1004    ABC123    PRD101         2      10.99    CUST101
# 4        1005    XYZ789    PRD104         1      15.99    CUST104
# 5        1006    ABC123    PRD101         4      10.99    CUST101
# 6        1007    LMN456    PRD105         3       8.49    CUST105
# 7        1008    DEF456    PRD102         5       5.49    CUST102
# 8        1009    ABC123    PRD101         3      10.99    CUST101
# 9        1010    XYZ789    PRD104         2      15.99    CUST104
# 10       1011    XYZ789    PRD104         1      15.99    CUST106
# 11       1012    ABC123    PRD101         2      10.99    CUST107
# 12       1013    XYZ789    PRD104         3      15.99    CUST108
# 13       1014    GHI789    PRD103         4       7.99    CUST109
# 14       1015    ABC123    PRD101         5      10.99    CUST110
# 15       1016    XYZ789    PRD104         2      15.99    CUST111
# 16       1017    ABC123    PRD101         1      10.99    CUST112
# 17       1018    XYZ789    PRD104         3      15.99    CUST113
# 18       1019    ABC123    PRD101         4      10.99    CUST114
# 19       1020    XYZ789    PRD104         5      15.99    CUST115
# 20       1021    ABC123    PRD101         2      10.99    CUST116
# 21       1022    XYZ789    PRD104         3      15.99    CUST117
# 22       1023    GHI789    PRD103         1       7.99    CUST118
# 23       1024    ABC123    PRD101         3      10.99    CUST119
# 24       1025    XYZ789    PRD104         4      15.99    CUST120
# 25       1026    ABC123    PRD101         5      10.99    CUST121
# 26       1027    XYZ789    PRD104         2      15.99    CUST122
# 27       1028    ABC123    PRD101         3      10.99    CUST123
# 28       1029    XYZ789    PRD104         1      15.99    CUST124
# 29       1030    ABC123    PRD101         4      10.99    CUST125

# %%
products = pd.read_excel(filename, sheet_name="products")
products
# Out:
#   ProductID    ProductName
# 0    PRD101   Baseball Bat
# 1    PRD102        T-Shirt
# 2    PRD103  Running Shoes
# 3    PRD104     Smartphone
# 4    PRD105         Laptop

# %%
customers = pd.read_excel(filename, sheet_name="customers")
customers
# Out:
#    CustomerID CustomerFirstName CustomerSurname                 CustomerEmail  \
# 0     CUST101              John             Doe          john.doe@example.com
# 1     CUST102             Alice           Smith       alice.smith@example.com
# 2     CUST103           Michael         Johnson   michael.johnson@example.com
# 3     CUST104             David           Brown                           NaN
# 4     CUST105            Robert          Miller     robert.miller@example.com
# 5     CUST106           Matthew          Martin    matthew.martin@example.com
# 6     CUST107           Jessica        Thompson                           NaN
# 7     CUST108           William           Clark     william.clark@example.com
# 8     CUST109             Karen            Hall                           NaN
# 9     CUST110            Steven           Allen      steven.allen@example.com
# 10    CUST111          Michelle           Lewis                           NaN
# 11    CUST112            Joseph           Scott                           NaN
# 12    CUST113          Patricia           Green    patricia.green@example.com
# 13    CUST114            Thomas            Hill       thomas.hill@example.com
# 14    CUST115          Jennifer            Hall     jennifer.hall@example.com
# 15    CUST116           Charles           Adams     charles.adams@example.com
# 16    CUST117           Dorothy           Baker                           NaN
# 17    CUST118              Mark          Wright                           NaN
# 18    CUST119         Elizabeth          Carter  elizabeth.carter@example.com
# 19    CUST120            Steven            Hall       steven.hall@example.com
# 20    CUST121             Donna          Turner      donna.turner@example.com
# 21    CUST122           Anthony           White     anthony.white@example.com
# 22    CUST123             Laura          Harris      laura.harris@example.com
# 23    CUST124           Charles          Martin    charles.martin@example.com
# 24    CUST125             Carol        Thompson    carol.thompson@example.com
#
#    CustomerCountry
# 0   United Kingdom
# 1          Germany
# 2           France
# 3   United Kingdom
# 4           France
# 5   United Kingdom
# 6   United Kingdom
# 7          Germany
# 8           France
# 9   United Kingdom
# 10  United Kingdom
# 11         Germany
# 12  United Kingdom
# 13          France
# 14  United Kingdom
# 15  United Kingdom
# 16         Germany
# 17  United Kingdom
# 18  United Kingdom
# 19          France
# 20  United Kingdom
# 21  United Kingdom
# 22         Germany
# 23  United Kingdom
# 24  United Kingdom

# %% [markdown]
# ## Manual Task Automation 1:
# We want the names of the top five customers by total spend in this data. We'll start by
# creating a new `OrderTotal` column to make the calculation easier. Then we'll group each
# customer together to get their total spend. Finally, we'll sort the customers by their
# total spend and only display the `numberToInclude`, in this case 5.

# %%
transactions["OrderTotal"] = transactions["Quantity"] * transactions["UnitPrice"]
orderLedger = transactions[["CustomerID", "OrderTotal"]]
numberToInclude = 5
topCustomerIdsBySpend = (
    orderLedger.groupby("CustomerID")
    .sum()
    .sort_values("OrderTotal", ascending=False)
    .head(numberToInclude)
)
topCustomerIdsBySpend
# Out:
#             OrderTotal
# CustomerID
# CUST101         153.86
# CUST115          79.95
# CUST120          63.96
# CUST121          54.95
# CUST110          54.95

# %% [markdown]
# Since we only have the customer IDs we now use them to look up the customers' first and
# last names.

# %%
top_customers = pd.merge(topCustomerIdsBySpend, customers, on="CustomerID")[
    ["CustomerFirstName", "CustomerSurname"]
]
top_customers
# Out:
#   CustomerFirstName CustomerSurname
# 0              John             Doe
# 1          Jennifer            Hall
# 2            Steven            Hall
# 3             Donna          Turner
# 4            Steven           Allen

# %% [markdown]
# It's time to export the data to a CSV file. To keep track of the files we will include
# today's date. Ideally the data would include the date it was created, but since it
# doesn't the date this pipeline is run will suffice. We are using `os.sep` for the
# directory so that this can run on difference operating systems without issue.

# %%
import datetime

today = datetime.datetime.now().strftime("%Y-%m-%d")

import os

top_customers.to_csv(
    f"exports{os.sep}XYZ-top-customers-{today}.csv", index=False, header=False
)

# %% [markdown]
# ## Data Transformation 1
#
# We are replacing blank email cells with the text "No Email" so that when the marketing
# team run their analysis all of the "No Email" cells will appear together. If instead
# the marketing team wanted to get an accurate count of unique users we could create
# unique user IDs for each customer so that they would not have to rely on emails as they
# do now.

# %%
# Enter value "No Email" in place of NaN in the email column
customers["CustomerEmail"].fillna("No Email", inplace=True)
customers
# Out:
#    CustomerID CustomerFirstName CustomerSurname                 CustomerEmail  \
# 0     CUST101              John             Doe          john.doe@example.com
# 1     CUST102             Alice           Smith       alice.smith@example.com
# 2     CUST103           Michael         Johnson   michael.johnson@example.com
# 3     CUST104             David           Brown                      No Email
# 4     CUST105            Robert          Miller     robert.miller@example.com
# 5     CUST106           Matthew          Martin    matthew.martin@example.com
# 6     CUST107           Jessica        Thompson                      No Email
# 7     CUST108           William           Clark     william.clark@example.com
# 8     CUST109             Karen            Hall                      No Email
# 9     CUST110            Steven           Allen      steven.allen@example.com
# 10    CUST111          Michelle           Lewis                      No Email
# 11    CUST112            Joseph           Scott                      No Email
# 12    CUST113          Patricia           Green    patricia.green@example.com
# 13    CUST114            Thomas            Hill       thomas.hill@example.com
# 14    CUST115          Jennifer            Hall     jennifer.hall@example.com
# 15    CUST116           Charles           Adams     charles.adams@example.com
# 16    CUST117           Dorothy           Baker                      No Email
# 17    CUST118              Mark          Wright                      No Email
# 18    CUST119         Elizabeth          Carter  elizabeth.carter@example.com
# 19    CUST120            Steven            Hall       steven.hall@example.com
# 20    CUST121             Donna          Turner      donna.turner@example.com
# 21    CUST122           Anthony           White     anthony.white@example.com
# 22    CUST123             Laura          Harris      laura.harris@example.com
# 23    CUST124           Charles          Martin    charles.martin@example.com
# 24    CUST125             Carol        Thompson    carol.thompson@example.com
#
#    CustomerCountry
# 0   United Kingdom
# 1          Germany
# 2           France
# 3   United Kingdom
# 4           France
# 5   United Kingdom
# 6   United Kingdom
# 7          Germany
# 8           France
# 9   United Kingdom
# 10  United Kingdom
# 11         Germany
# 12  United Kingdom
# 13          France
# 14  United Kingdom
# 15  United Kingdom
# 16         Germany
# 17  United Kingdom
# 18  United Kingdom
# 19          France
# 20  United Kingdom
# 21  United Kingdom
# 22         Germany
# 23  United Kingdom
# 24  United Kingdom

# %% [markdown]
# ## Data transformations 2 and 3
# We need to export our data in parquet format.
#
# It also needs to be clear when it was processed. We have three options to do so: We
# could add the date to the file, but would needlessly increase the size if we had to
# include it on each row. We could add something to the file's metadata, which might be
# useful if we knew more about the program the marketing team are using. Third, we can
# include the date once again in the filename. This is the simplest solution and also the
# most widely supported since virtually every program will display filenames and sort
# alphabetically by them. As such, we are using this solution.
#
# First we drop the `OrderTotal` column from transactions, since we don't need it anymore.
# The we use Pandas and fastparquet to export the parquet file. We repeat for all the data.

# %%
transactions.drop(columns=["OrderTotal"], inplace=True)
transactions
# Out:
#     InvoiceNo StockCode ProductID  Quantity  UnitPrice CustomerID
# 0        1001    ABC123    PRD101         5      10.99    CUST101
# 1        1002    DEF456    PRD102         3       5.49    CUST102
# 2        1003    GHI789    PRD103         2       7.99    CUST103
# 3        1004    ABC123    PRD101         2      10.99    CUST101
# 4        1005    XYZ789    PRD104         1      15.99    CUST104
# 5        1006    ABC123    PRD101         4      10.99    CUST101
# 6        1007    LMN456    PRD105         3       8.49    CUST105
# 7        1008    DEF456    PRD102         5       5.49    CUST102
# 8        1009    ABC123    PRD101         3      10.99    CUST101
# 9        1010    XYZ789    PRD104         2      15.99    CUST104
# 10       1011    XYZ789    PRD104         1      15.99    CUST106
# 11       1012    ABC123    PRD101         2      10.99    CUST107
# 12       1013    XYZ789    PRD104         3      15.99    CUST108
# 13       1014    GHI789    PRD103         4       7.99    CUST109
# 14       1015    ABC123    PRD101         5      10.99    CUST110
# 15       1016    XYZ789    PRD104         2      15.99    CUST111
# 16       1017    ABC123    PRD101         1      10.99    CUST112
# 17       1018    XYZ789    PRD104         3      15.99    CUST113
# 18       1019    ABC123    PRD101         4      10.99    CUST114
# 19       1020    XYZ789    PRD104         5      15.99    CUST115
# 20       1021    ABC123    PRD101         2      10.99    CUST116
# 21       1022    XYZ789    PRD104         3      15.99    CUST117
# 22       1023    GHI789    PRD103         1       7.99    CUST118
# 23       1024    ABC123    PRD101         3      10.99    CUST119
# 24       1025    XYZ789    PRD104         4      15.99    CUST120
# 25       1026    ABC123    PRD101         5      10.99    CUST121
# 26       1027    XYZ789    PRD104         2      15.99    CUST122
# 27       1028    ABC123    PRD101         3      10.99    CUST123
# 28       1029    XYZ789    PRD104         1      15.99    CUST124
# 29       1030    ABC123    PRD101         4      10.99    CUST125

# %%
transactions_path = f"exports{os.sep}XYZ-transactions-{today}.parquet"
transactions.to_parquet(transactions_path)
pd.read_parquet(transactions_path)
# Out:
#     InvoiceNo StockCode ProductID  Quantity  UnitPrice CustomerID
# 0        1001    ABC123    PRD101         5      10.99    CUST101
# 1        1002    DEF456    PRD102         3       5.49    CUST102
# 2        1003    GHI789    PRD103         2       7.99    CUST103
# 3        1004    ABC123    PRD101         2      10.99    CUST101
# 4        1005    XYZ789    PRD104         1      15.99    CUST104
# 5        1006    ABC123    PRD101         4      10.99    CUST101
# 6        1007    LMN456    PRD105         3       8.49    CUST105
# 7        1008    DEF456    PRD102         5       5.49    CUST102
# 8        1009    ABC123    PRD101         3      10.99    CUST101
# 9        1010    XYZ789    PRD104         2      15.99    CUST104
# 10       1011    XYZ789    PRD104         1      15.99    CUST106
# 11       1012    ABC123    PRD101         2      10.99    CUST107
# 12       1013    XYZ789    PRD104         3      15.99    CUST108
# 13       1014    GHI789    PRD103         4       7.99    CUST109
# 14       1015    ABC123    PRD101         5      10.99    CUST110
# 15       1016    XYZ789    PRD104         2      15.99    CUST111
# 16       1017    ABC123    PRD101         1      10.99    CUST112
# 17       1018    XYZ789    PRD104         3      15.99    CUST113
# 18       1019    ABC123    PRD101         4      10.99    CUST114
# 19       1020    XYZ789    PRD104         5      15.99    CUST115
# 20       1021    ABC123    PRD101         2      10.99    CUST116
# 21       1022    XYZ789    PRD104         3      15.99    CUST117
# 22       1023    GHI789    PRD103         1       7.99    CUST118
# 23       1024    ABC123    PRD101         3      10.99    CUST119
# 24       1025    XYZ789    PRD104         4      15.99    CUST120
# 25       1026    ABC123    PRD101         5      10.99    CUST121
# 26       1027    XYZ789    PRD104         2      15.99    CUST122
# 27       1028    ABC123    PRD101         3      10.99    CUST123
# 28       1029    XYZ789    PRD104         1      15.99    CUST124
# 29       1030    ABC123    PRD101         4      10.99    CUST125

# %%
customers_path = f"exports{os.sep}XYZ-customers-{today}.parquet"
customers.to_parquet(customers_path)
pd.read_parquet(customers_path)
# Out:
#    CustomerID CustomerFirstName CustomerSurname                 CustomerEmail  \
# 0     CUST101              John             Doe          john.doe@example.com
# 1     CUST102             Alice           Smith       alice.smith@example.com
# 2     CUST103           Michael         Johnson   michael.johnson@example.com
# 3     CUST104             David           Brown                      No Email
# 4     CUST105            Robert          Miller     robert.miller@example.com
# 5     CUST106           Matthew          Martin    matthew.martin@example.com
# 6     CUST107           Jessica        Thompson                      No Email
# 7     CUST108           William           Clark     william.clark@example.com
# 8     CUST109             Karen            Hall                      No Email
# 9     CUST110            Steven           Allen      steven.allen@example.com
# 10    CUST111          Michelle           Lewis                      No Email
# 11    CUST112            Joseph           Scott                      No Email
# 12    CUST113          Patricia           Green    patricia.green@example.com
# 13    CUST114            Thomas            Hill       thomas.hill@example.com
# 14    CUST115          Jennifer            Hall     jennifer.hall@example.com
# 15    CUST116           Charles           Adams     charles.adams@example.com
# 16    CUST117           Dorothy           Baker                      No Email
# 17    CUST118              Mark          Wright                      No Email
# 18    CUST119         Elizabeth          Carter  elizabeth.carter@example.com
# 19    CUST120            Steven            Hall       steven.hall@example.com
# 20    CUST121             Donna          Turner      donna.turner@example.com
# 21    CUST122           Anthony           White     anthony.white@example.com
# 22    CUST123             Laura          Harris      laura.harris@example.com
# 23    CUST124           Charles          Martin    charles.martin@example.com
# 24    CUST125             Carol        Thompson    carol.thompson@example.com
#
#    CustomerCountry
# 0   United Kingdom
# 1          Germany
# 2           France
# 3   United Kingdom
# 4           France
# 5   United Kingdom
# 6   United Kingdom
# 7          Germany
# 8           France
# 9   United Kingdom
# 10  United Kingdom
# 11         Germany
# 12  United Kingdom
# 13          France
# 14  United Kingdom
# 15  United Kingdom
# 16         Germany
# 17  United Kingdom
# 18  United Kingdom
# 19          France
# 20  United Kingdom
# 21  United Kingdom
# 22         Germany
# 23  United Kingdom
# 24  United Kingdom

# %%
products_path = f"exports{os.sep}XYZ-products-{today}.parquet"
products.to_parquet(products_path)
pd.read_parquet(products_path)
# Out:
#   ProductID    ProductName
# 0    PRD101   Baseball Bat
# 1    PRD102        T-Shirt
# 2    PRD103  Running Shoes
# 3    PRD104     Smartphone
# 4    PRD105         Laptop

# %%
top_customers_parquet_path = f"exports{os.sep}XYZ-top-customers-{today}.parquet"
top_customers.to_parquet(top_customers_parquet_path)
pd.read_parquet(top_customers_parquet_path)
# Out:
#   CustomerFirstName CustomerSurname
# 0              John             Doe
# 1          Jennifer            Hall
# 2            Steven            Hall
# 3             Donna          Turner
# 4            Steven           Allen

# %% [markdown]
# ## Thanks for reading!
# To run this in production use the Python script and Dockerfile as described in the
# readme file.
